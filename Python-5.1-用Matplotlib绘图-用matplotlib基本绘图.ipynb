# %% [markdown]
# # 用Matplotlib绘图-用matplotlib基本绘图
# 微软专业学位课程 - 选修DAT208X
# * Introduction to Python for Data Science:https://www.msaischool.com/courses/course-v1:Microsoft+DAT208x+2017_T4/about
#
# Matplotlib文档：
# * 官方主页：https://matplotlib.org/index.html
# * 官方教程：https://matplotlib.org/tutorials/index.html
# * 官方示例：https://matplotlib.org/gallery/index.html

# %% [markdown]
# ## 折线图
# ```python
# import matplotlib.pyplot as plt
# plt.plot(x,y)
# plt.show()
# ```

# %%
# Print the last item from year and pop
year = [1999, 2000, 2001, 2002]
pop = [35, 36, 43, 45]

# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Make a line plot: year on the x-axis, pop on the y-axis
plt.plot(year,pop)
plt.show()

# %% [markdown]
# ## 散点图
# ```python
# import matplotlib.pyplot as plt
# plt.scatter(x,y)
# plt.show()
# ```

# %%
# Print the last item from year and pop
gdp_cap = [1999, 2000, 2001, 2002]
life_exp = [35, 36, 43, 45]

# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Change the line plot below to a scatter plot
plt.scatter(gdp_cap, life_exp)

# Put the x-axis on a logarithmic scale
plt.xscale('log')

# Show plot
plt.show()
